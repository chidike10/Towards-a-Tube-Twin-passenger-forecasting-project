# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import plotly
import seaborn as sns

# %%
data = pd.read_csv("tube_time_interval_data.csv")

# %%
data.head()
# Out:
#     entry_date_time   time mode  nlc   asc       station  \
# 0  2017-12-26 05:15  05:15   LU  500  ACTu    Acton Town
# 1  2017-12-26 05:15  05:15   LU  502  ALDu       Aldgate
# 2  2017-12-26 05:15  05:15   LU  503  ALEu  Aldgate East
# 3  2017-12-26 05:15  05:15   LU  505  ALPu      Alperton
# 4  2017-12-26 05:15  05:15   LU  506  AMEu      Amersham
#
#                coverage  year_of_entry  day dir time_intervals  counts
# 0  Station entry / exit           2017  MTF  IN      0500-0515    22.0
# 1  Station entry / exit           2017  MTF  IN      0500-0515    11.0
# 2  Station entry / exit           2017  MTF  IN      0500-0515     6.0
# 3  Station entry / exit           2017  MTF  IN      0500-0515    15.0
# 4  Station entry / exit           2017  MTF  IN      0500-0515     1.0

# %%
data.shape
# Out:
# (964800, 12)

# %%
# # Setting the date column as the index column
# data = data.set_index('entry_date_time')
# data.head()

# %%
data.shape
# Out:
# (964800, 12)

# %%
data_in = data.loc[data.dir=='IN']
data_in.head()
# Out:
#     entry_date_time   time mode  nlc   asc       station  \
# 0  2017-12-26 05:15  05:15   LU  500  ACTu    Acton Town
# 1  2017-12-26 05:15  05:15   LU  502  ALDu       Aldgate
# 2  2017-12-26 05:15  05:15   LU  503  ALEu  Aldgate East
# 3  2017-12-26 05:15  05:15   LU  505  ALPu      Alperton
# 4  2017-12-26 05:15  05:15   LU  506  AMEu      Amersham
#
#                coverage  year_of_entry  day dir time_intervals  counts
# 0  Station entry / exit           2017  MTF  IN      0500-0515    22.0
# 1  Station entry / exit           2017  MTF  IN      0500-0515    11.0
# 2  Station entry / exit           2017  MTF  IN      0500-0515     6.0
# 3  Station entry / exit           2017  MTF  IN      0500-0515    15.0
# 4  Station entry / exit           2017  MTF  IN      0500-0515     1.0

# %%
data_in.shape
# Out:
# (482400, 12)

# %%
data_out = data.loc[data.dir=='OUT']
data_out.head()
# Out:
#       entry_date_time   time mode  nlc   asc       station  \
# 263  2017-12-26 05:15  05:15   LU  500  ACTu    Acton Town
# 264  2017-12-26 05:15  05:15   LU  502  ALDu       Aldgate
# 265  2017-12-26 05:15  05:15   LU  503  ALEu  Aldgate East
# 266  2017-12-26 05:15  05:15   LU  505  ALPu      Alperton
# 267  2017-12-26 05:15  05:15   LU  506  AMEu      Amersham
#
#                  coverage  year_of_entry  day  dir time_intervals  counts
# 263  Station entry / exit           2017  MTF  OUT      0500-0515     1.0
# 264  Station entry / exit           2017  MTF  OUT      0500-0515     9.0
# 265  Station entry / exit           2017  MTF  OUT      0500-0515     0.0
# 266  Station entry / exit           2017  MTF  OUT      0500-0515     0.0
# 267  Station entry / exit           2017  MTF  OUT      0500-0515     0.0

# %%
data_out.shape
# Out:
# (482400, 12)

# %%
# Setting the dataframe manipulation results to show all the rows and columns without breaking
pd.set_option("display.max_columns", None)

pd.set_option("display.max_rows", None)

# %%
data_in_sorted = data_in.sort_values('asc')

# %%
data_in_sorted.head()
# Out:
#          entry_date_time   time mode  nlc  asc     station  \
# 534228  2018-12-25 18:30  18:30   LU  500  ACT  Acton Town
# 32788   2018-12-27 06:00  06:00   LU  500  ACT  Acton Town
# 686568  2018-12-28 22:15  22:15   LU  500  ACT  Acton Town
# 686038  2018-12-27 22:15  22:15   LU  500  ACT  Acton Town
# 685508  2018-12-26 22:15  22:15   LU  500  ACT  Acton Town
#
#                     coverage  year_of_entry  day dir time_intervals  counts
# 534228  Station entry / exit           2018  MTT  IN      1815-1830   154.0
# 32788   Station entry / exit           2018  SAT  IN      0545-0600    21.0
# 686568  Station entry / exit           2018  SUN  IN      2200-2215    22.0
# 686038  Station entry / exit           2018  SAT  IN      2200-2215    38.0
# 685508  Station entry / exit           2018  FRI  IN      2200-2215    39.0

# %%
data_in_sorted.sort_values(['asc', 'time'], ascending=[True, True]).head(500)
# Out:
#          entry_date_time   time mode  nlc   asc     station  \
# 755858  2018-12-26 00:00  00:00   LU  500   ACT  Acton Town
# 755328  2018-12-25 00:00  00:00   LU  500   ACT  Acton Town
# 756918  2018-12-28 00:00  00:00   LU  500   ACT  Acton Town
# 756388  2018-12-27 00:00  00:00   LU  500   ACT  Acton Town
# 766968  2018-12-28 00:15  00:15   LU  500   ACT  Acton Town
# 766438  2018-12-27 00:15  00:15   LU  500   ACT  Acton Town
# 765908  2018-12-26 00:15  00:15   LU  500   ACT  Acton Town
# 765378  2018-12-25 00:15  00:15   LU  500   ACT  Acton Town
# 777018  2018-12-28 00:30  00:30   LU  500   ACT  Acton Town
# 776488  2018-12-27 00:30  00:30   LU  500   ACT  Acton Town
# 775428  2018-12-25 00:30  00:30   LU  500   ACT  Acton Town
# 775958  2018-12-26 00:30  00:30   LU  500   ACT  Acton Town
# 787068  2018-12-28 00:45  00:45   LU  500   ACT  Acton Town
# 786538  2018-12-27 00:45  00:45   LU  500   ACT  Acton Town
# 786008  2018-12-26 00:45  00:45   LU  500   ACT  Acton Town
# ...

# %%
data_in_sorted['station'].unique()
# Out:
# array(['Acton Town', 'Arnos Grove', 'Aldgate', 'Aldgate East', 'Alperton',
#        'Amersham', 'Angel', 'Archway', 'Arsenal', 'Balham LU', 'Barbican',
#        'Bayswater', 'Bromley-by-Bow', 'Barons Court', 'Barkingside',
#        'Bond Street', 'Becontree', 'Bermondsey', 'Bounds Green',
#        'Buckhurst Hill', 'Blackhorse Road', 'Barking', 'Blackfriars LU',
#        'Bethnal Green LU', 'Bank and Monument', 'Borough', 'Boston Manor',
#        'Belsize Park', 'Battersea Power Station', 'Brixton LU',
#        'Baker Street', 'Brent Cross', 'Burnt Oak', 'Bow Road',
#        'Cockfosters', 'Chalk Farm', 'Chigwell', 'Chesham',
#        'Chiswick Park', 'Charing Cross LU', 'Chalfont & Latimer',
#        'Colliers Wood', 'Canning Town', 'Colindale', 'Covent Garden',
#        'Clapham Common', 'Canons Park', 'Clapham North', 'Clapham South',
#        'Caledonian Road', 'Croxley', 'Cannon Street LU', 'Camden Town',
# ...

# %%
# data_out_sorted = data_out.sort_values('asc')

# %%
# data_out_sorted.sort_values(['asc', 'time'], ascending=[True, True]).head(10)

# %%
list_station = ['Acton Town', 'Arnos Grove', 'Aldgate', 'Aldgate East', 'Alperton',
       'Amersham', 'Angel', 'Archway', 'Arsenal', 'Balham LU', 'Barbican',
       'Bayswater', 'Bromley-by-Bow', 'Barons Court', 'Barkingside',]
list_day = ['MTT', 'FRI', 'SAT', 'SUN']
list_dir = ['IN', 'OUT']

# %%
x = str input()
y = str input()
z = str input()

if x in list_station:
    print(x)
if y in list_station:
    print(y)
if z in list_station:
    print(z)

# for x in list_station:
#     if input() == x:
#         for y in list_day:
#             if input() == y:
#                 for z in list_dir:
#                     if input() == z:
#                         break

# %%
def get_data(df, station, day):
    
    df = df
    station = station
    day = day
    
    data_in_sorted = df.sort_values(['asc', 'time'], ascending=[True, True])
    df_in_new = data_in_sorted.loc[data_in_sorted.station==station]
    df_in_new = df_in_new.loc[df_in_new.day==day]
    
    df_in_new = df_in_new.sort_values(['year_of_entry'], ascending=True)
    df_in_new = df_in_new[['entry_date_time', 'counts']]
    
    return df_in_new

# %%
# def forecast_data(df, station, day):
    
#     for i, k in df.columns:
#         if df.loc[df.columns[i]=='station'] and df.loc[df.columns[i+3]=='day']:
#             new_df = df.loc[df.=='OUT']

# %%
data_in_sorted.to_csv('london_tube_passenger_in.csv', index=False)

# %%
data_out_sorted.to_csv('london_tube_passenger_out.csv', index=False)

# %%
data_lu_in = pd.read_csv('london_tube_passenger_in.csv')
data_lu_out = pd.read_csv('london_tube_passenger_out.csv')

# %%
data_lu_in.head()
# Out:
#     entry_date_time   time mode  nlc  asc     station              coverage  \
# 0  2018-12-25 18:30  18:30   LU  500  ACT  Acton Town  Station entry / exit
# 1  2018-12-27 06:00  06:00   LU  500  ACT  Acton Town  Station entry / exit
# 2  2018-12-28 22:15  22:15   LU  500  ACT  Acton Town  Station entry / exit
# 3  2018-12-27 22:15  22:15   LU  500  ACT  Acton Town  Station entry / exit
# 4  2018-12-26 22:15  22:15   LU  500  ACT  Acton Town  Station entry / exit
#
#    year_of_entry  day dir time_intervals  counts
# 0           2018  MTT  IN      1815-1830   154.0
# 1           2018  SAT  IN      0545-0600    21.0
# 2           2018  SUN  IN      2200-2215    22.0
# 3           2018  SAT  IN      2200-2215    38.0
# 4           2018  FRI  IN      2200-2215    39.0

# %%
data_lu_out.head()
# Out:
#     entry_date_time   time mode  nlc  asc     station              coverage  \
# 0  2018-12-25 18:30  18:30   LU  500  ACT  Acton Town  Station entry / exit
# 1  2018-12-27 06:00  06:00   LU  500  ACT  Acton Town  Station entry / exit
# 2  2018-12-28 22:15  22:15   LU  500  ACT  Acton Town  Station entry / exit
# 3  2018-12-27 22:15  22:15   LU  500  ACT  Acton Town  Station entry / exit
# 4  2018-12-26 22:15  22:15   LU  500  ACT  Acton Town  Station entry / exit
#
#    year_of_entry  day  dir time_intervals  counts
# 0           2018  MTT  OUT      1815-1830   291.0
# 1           2018  SAT  OUT      0545-0600    10.0
# 2           2018  SUN  OUT      2200-2215    82.0
# 3           2018  SAT  OUT      2200-2215    83.0
# 4           2018  FRI  OUT      2200-2215    97.0

# %%
df_in_new = data_in_sorted.loc[data_in_sorted.station=='Acton Town']
df_in_new = df_in_new.loc[df_in_new.day=='MTT']

# %%
get_data(data_lu_in, 'Acton Town', 'SUN')
# Out:
#        entry_date_time   counts
# 1755  2017-12-28 23:45   12.000
# 706   2017-12-28 06:30   25.000
# 453   2017-12-28 06:45   27.000
# 1197  2017-12-28 07:00   34.000
# 981   2017-12-28 07:15   44.000
# 927   2017-12-28 07:30   48.000
# 1544  2017-12-28 07:45   43.000
# 1411  2017-12-28 08:00   43.000
# 1417  2017-12-28 08:15   51.000
# 1543  2017-12-28 08:30   60.000
# 1742  2017-12-28 06:15   22.000
# 687   2017-12-28 08:45   63.000
# 491   2017-12-28 09:15   78.000
# 599   2017-12-28 09:30   81.000
# 1131  2017-12-28 09:45   81.000
# 1248  2017-12-28 10:00   86.000
# 878   2017-12-28 10:15  104.000
# 1041  2017-12-28 10:30  110.000
# 1038  2017-12-28 10:45  107.000
# 1011  2017-12-28 11:00  104.000
# 1074  2017-12-28 11:15  110.000
# 859   2017-12-28 09:00   69.000
# 984   2017-12-28 11:30  114.000
# 1728  2017-12-28 06:00   16.000
# 1275  2017-12-28 05:30   10.000
# 724   2017-12-28 00:30    1.000
# 683   2017-12-28 00:45    1.000
# 773   2017-12-28 01:00    0.000
# ...

# %%
df_in_new.head()
# Out:
#          entry_date_time   time mode  nlc  asc     station  \
# 534228  2018-12-25 18:30  18:30   LU  500  ACT  Acton Town
# 684978  2018-12-25 22:15  22:15   LU  500  ACT  Acton Town
# 674928  2018-12-25 22:00  22:00   LU  500  ACT  Acton Town
# 664878  2018-12-25 21:45  21:45   LU  500  ACT  Acton Town
# 654828  2018-12-25 21:30  21:30   LU  500  ACT  Acton Town
#
#                     coverage  year_of_entry  day dir time_intervals  counts
# 534228  Station entry / exit           2018  MTT  IN      1815-1830   154.0
# 684978  Station entry / exit           2018  MTT  IN      2200-2215    27.0
# 674928  Station entry / exit           2018  MTT  IN      2145-2200    23.0
# 664878  Station entry / exit           2018  MTT  IN      2130-2145    28.0
# 654828  Station entry / exit           2018  MTT  IN      2115-2130    34.0

# %%
df_in_2021_mtt = df_in_new.loc[df_in_new.year_of_entry==2021]

# %%
df_in_2021_mtt.head()
# Out:
#          entry_date_time   time mode  nlc   asc     station  \
# 430030  2021-12-25 15:45  15:45   LU  500  ACTu  Acton Town
# 17980   2021-12-25 05:30  05:30   LU  500  ACTu  Acton Town
# 962680  2021-12-25 05:00  05:00   LU  500  ACTu  Acton Town
# 419980  2021-12-25 15:30  15:30   LU  500  ACTu  Acton Town
# 450130  2021-12-25 16:15  16:15   LU  500  ACTu  Acton Town
#
#                     coverage  year_of_entry  day dir time_intervals  \
# 430030  Station entry / exit           2021  MTT  IN      1530-1545
# 17980   Station entry / exit           2021  MTT  IN      0515-0530
# 962680  Station entry / exit           2021  MTT  IN      0445-0500
# 419980  Station entry / exit           2021  MTT  IN      1515-1530
# 450130  Station entry / exit           2021  MTT  IN      1600-1615
#
#             counts
# 430030  145.333330
# 17980    30.055555
# 962680   17.055555
# 419980  114.888885
# 450130  160.611110

# %%
df_in_2021_mtt.shape
# Out:
# (96, 12)

# %%
df_in_2021_mtt = df_in_2021_mtt[['entry_date_time', 'counts']]

# %%
df_in_2021_mtt.head()
# Out:
#          entry_date_time      counts
# 430030  2021-12-25 15:45  145.333330
# 17980   2021-12-25 05:30   30.055555
# 962680  2021-12-25 05:00   17.055555
# 419980  2021-12-25 15:30  114.888885
# 450130  2021-12-25 16:15  160.611110

# %%
df_in_2021_mtt.to_csv('df_in_2021_mtt.csv', index=False)

# %%
df_in_new.head()
# Out:
#          entry_date_time   time mode  nlc  asc     station  \
# 534228  2018-12-25 18:30  18:30   LU  500  ACT  Acton Town
# 684978  2018-12-25 22:15  22:15   LU  500  ACT  Acton Town
# 674928  2018-12-25 22:00  22:00   LU  500  ACT  Acton Town
# 664878  2018-12-25 21:45  21:45   LU  500  ACT  Acton Town
# 654828  2018-12-25 21:30  21:30   LU  500  ACT  Acton Town
#
#                     coverage  year_of_entry  day dir time_intervals  counts
# 534228  Station entry / exit           2018  MTT  IN      1815-1830   154.0
# 684978  Station entry / exit           2018  MTT  IN      2200-2215    27.0
# 674928  Station entry / exit           2018  MTT  IN      2145-2200    23.0
# 664878  Station entry / exit           2018  MTT  IN      2130-2145    28.0
# 654828  Station entry / exit           2018  MTT  IN      2115-2130    34.0

# %%
df_in_new.shape
# Out:
# (384, 12)

# %%
df = df_in_new[['entry_date_time', 'nlc', 'day', 'counts']]
df.head()
# Out:
#          entry_date_time  nlc  day  counts
# 534228  2018-12-25 18:30  500  MTT   154.0
# 684978  2018-12-25 22:15  500  MTT    27.0
# 674928  2018-12-25 22:00  500  MTT    23.0
# 664878  2018-12-25 21:45  500  MTT    28.0
# 654828  2018-12-25 21:30  500  MTT    34.0

# %%
df.to_csv('acton_station_data.csv', index=False)

# %%
from tsfresh import extract_features, extract_relevant_features, select_features
from tsfresh.utilities.dataframe_functions import impute, make_forecasting_frame
from tsfresh.feature_extraction import ComprehensiveFCParameters, settings

# %%
df_pass, y_count = make_forecasting_frame(df["counts"], kind="Passenger Count", max_timeshift=12, rolling_direction=1)
print(df_pass)
# Out:
# Rolling: 100%|█████████████████████████████████████████████████████████████████████████| 10/10 [00:05<00:00,  1.67it/s]
#                           id              time       value             kind
# 1     (id, 2018-12-25 00:15)  2018-12-25 00:00    9.000000  Passenger Count
# 3     (id, 2018-12-25 00:30)  2018-12-25 00:00    9.000000  Passenger Count
# 4     (id, 2018-12-25 00:30)  2018-12-25 00:15    6.000000  Passenger Count
# 6     (id, 2018-12-25 00:45)  2018-12-25 00:00    9.000000  Passenger Count
# 7     (id, 2018-12-25 00:45)  2018-12-25 00:15    6.000000  Passenger Count
# 8     (id, 2018-12-25 00:45)  2018-12-25 00:30    4.000000  Passenger Count
# 10    (id, 2018-12-25 01:00)  2018-12-25 00:00    9.000000  Passenger Count
# 11    (id, 2018-12-25 01:00)  2018-12-25 00:15    6.000000  Passenger Count
# 12    (id, 2018-12-25 01:00)  2018-12-25 00:30    4.000000  Passenger Count
# 13    (id, 2018-12-25 01:00)  2018-12-25 00:45    4.000000  Passenger Count
# ...

# %%
extraction_settings = ComprehensiveFCParameters()
features = extract_features(df_pass, column_id="id", column_sort="time", column_value="value", impute_function=impute,
                     show_warnings=False,
                     default_fc_parameters=extraction_settings
                     )
# Out:
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████| 10/10 [00:18<00:00,  1.83s/it]

# %%
features.head()
# Out:
#                      value__variance_larger_than_standard_deviation  \
# id 2018-12-25 00:15                                             0.0
#    2018-12-25 00:30                                             1.0
#    2018-12-25 00:45                                             1.0
#    2018-12-25 01:00                                             1.0
#    2018-12-25 01:15                                             1.0
#
#                      value__has_duplicate_max  value__has_duplicate_min  \
# id 2018-12-25 00:15                       0.0                       0.0
#    2018-12-25 00:30                       0.0                       0.0
#    2018-12-25 00:45                       0.0                       0.0
#    2018-12-25 01:00                       0.0                       1.0
#    2018-12-25 01:15                       0.0                       0.0
#
#                      value__has_duplicate  value__sum_values  \
# ...

# %%
from tsfresh.utilities.dataframe_functions import impute
impute(features).head()
# Out:
#                      value__variance_larger_than_standard_deviation  \
# id 2018-12-25 00:15                                             0.0
#    2018-12-25 00:30                                             1.0
#    2018-12-25 00:45                                             1.0
#    2018-12-25 01:00                                             1.0
#    2018-12-25 01:15                                             1.0
#
#                      value__has_duplicate_max  value__has_duplicate_min  \
# id 2018-12-25 00:15                       0.0                       0.0
#    2018-12-25 00:30                       0.0                       0.0
#    2018-12-25 00:45                       0.0                       0.0
#    2018-12-25 01:00                       0.0                       1.0
#    2018-12-25 01:15                       0.0                       0.0
#
#                      value__has_duplicate  value__sum_values  \
# ...

# %%
from tsfresh import select_features
filtered_features = select_features(features, y_count)
filtered_features
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\GTITEC~1\AppData\Local\Temp/ipykernel_1116/3614673995.py in <module>
#       1 from tsfresh import select_features
# ----> 2 filtered_features = select_features(features, y_count)
#       3 filtered_features
#
# C:\anaconda\lib\site-packages\tsfresh\feature_selection\selection.py in select_features(X, y, test_for_binary_target_binary_feature, test_for_binary_target_real_feature, test_for_real_target_binary_feature, test_for_real_target_real_feature, fdr_level, hypotheses_independent, n_jobs, show_warnings, chunksize, ml_task, multiclass, n_significant)
#     158
#     159     if isinstance(y, pd.Series) and set(X.index) != set(y.index):
# --> 160         raise ValueError("Index of X and y must be identical if provided")
#     161
#     162     if isinstance(y, np.ndarray):
#
# ...

# %%
y_count.shape
# Out:
# (383,)

# %%
y_count.head()
# Out:
# (id, 2018-12-25 22:15)    27.0
# (id, 2018-12-25 22:00)    23.0
# (id, 2018-12-25 21:45)    28.0
# (id, 2018-12-25 21:30)    34.0
# (id, 2018-12-25 22:30)    26.0
# Name: value, dtype: float64

# %%
features.shape
# Out:
# (383, 789)

# %%
pip install darts --user
# Out:
# ...
#
# ...

# %%
from darts.models import ExponentialSmoothing

# %%
df_in_darts = df_in_new.reset_index('entry_date_time')
df_in_darts.head()
# Out:
#     entry_date_time   time mode  nlc  asc     station              coverage  \
# 0  2018-12-25 18:30  18:30   LU  500  ACT  Acton Town  Station entry / exit
# 1  2018-12-25 22:15  22:15   LU  500  ACT  Acton Town  Station entry / exit
# 2  2018-12-25 22:00  22:00   LU  500  ACT  Acton Town  Station entry / exit
# 3  2018-12-25 21:45  21:45   LU  500  ACT  Acton Town  Station entry / exit
# 4  2018-12-25 21:30  21:30   LU  500  ACT  Acton Town  Station entry / exit
#
#    year_of_entry  day dir time_intervals  counts
# 0           2018  MTT  IN      1815-1830   154.0
# 1           2018  MTT  IN      2200-2215    27.0
# 2           2018  MTT  IN      2145-2200    23.0
# 3           2018  MTT  IN      2130-2145    28.0
# 4           2018  MTT  IN      2115-2130    34.0

# %%
#Loading the package
from darts import TimeSeries
from darts.models import ExponentialSmoothing

# %%
# Create a TimeSeries, specifying the time and value columns
series = TimeSeries.from_dataframe(df_in_darts, 'entry_date_time', 'counts')

# Set aside the last 76 records (represents 20%) as a validation series
train, val = series[:-308], series[-76:]
# Out:
# 2022-09-26 16:16:19 darts.timeseries ERROR: ValueError: The time index of the provided DataArray is missing the freq attribute, and the frequency could not be directly inferred. This probably comes from inconsistent date frequencies with missing dates. If you know the actual frequency, try setting `fill_missing_dates=True, freq=actual_frequency`. If not, try setting `fill_missing_dates=True, freq=None` to see if a frequency can be inferred.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\GTITEC~1\AppData\Local\Temp/ipykernel_3336/2155078421.py in <module>
#       1 # Create a TimeSeries, specifying the time and value columns
# ----> 2 series = TimeSeries.from_dataframe(df_in_darts, 'entry_date_time', 'counts')
#       3
#       4 # Set aside the last 76 records (represents 20%) as a validation series
#       5 train, val = series[:-308], series[-76:]
#
# ...

# %%
df_in_new.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\GTITEC~1\AppData\Local\Temp/ipykernel_3336/2468584337.py in <module>
# ----> 1 df_in_new.shape
#
# NameError: name 'df_in_new' is not defined

# %%
model = ExponentialSmoothing()
model.fit(train)
prediction = model.predict(len(val), num_samples=1000)
