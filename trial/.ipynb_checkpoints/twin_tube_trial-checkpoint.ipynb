# %% [markdown]
# # Import Library Packages

# %% [markdown]
# In python data analysis, there are a lot of packages that would be required for different tasks at one level or the other. To be able to carry out almost all of our tasks, we would need the functions that are embedded in this packages or libraries, and for this primary reason, all the necessary libraries would have to be ***imported*** before use.
#
# In this project, we would be making use of a handful of the Pyhton packages wchich includes but not limited to the following:
#
# ***Pandas***
#
# ***Numpy***
#
# ***Matplotlib***

# %%
#Importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date
from datetime import time
from datetime import datetime

# %% [markdown]
# ### Importing the new dataset

# %%
df2 = pd.read_csv('tube_station_entry_exit_trial.csv')

# %%
df2.head()
# Out:
#   Mode  NLC   ASC       Station              Coverage  year  day  dir  \
# 0   LU  500  ACTu    Acton Town  Station entry / exit  2020  MTT   IN
# 1   LU  502  ALDu       Aldgate  Station entry / exit  2020  MTT   IN
# 2   LU  503  ALEu  Aldgate East  Station entry / exit  2020  MTT   IN
# 3   LU  505  ALPu      Alperton  Station entry / exit  2020  MTT   IN
# 4   LU  506  AMEu      Amersham  Station entry / exit  2020  MTT   IN
#
#          Total  Early       ...  0230-0245  0245-0300  0300-0315  0315-0330  \
# 0  3701.900000  288.200000  ...          0          0          0          0
# 1  2489.416667  172.583333  ...          0          0          0          0
# 2  3198.307692  103.000000  ...          0          0          0          0
# 3  2072.538462  360.230769  ...          0          0          0          0
# 4   980.466667  148.400000  ...          0          0          0          0
#
#    0330-0345  0345-0400  0400-0415  0415-0430  0430-0445  0445-0500
# ...

# %%
print(df2.columns)
# Out:
# Index(['Mode', 'NLC', 'ASC', 'Station', 'Coverage', 'year', ' day', ' dir',
#        'Total', 'Early     ',
#        ...
#        '0230-0245', '0245-0300', '0300-0315', '0315-0330', '0330-0345',
#        '0345-0400', '0400-0415', '0415-0430', '0430-0445', '0445-0500'],
#       dtype='object', length=111)

# %% [markdown]
# ### Remove spaces from all column names

# %%
df2.columns = df2.columns.str.replace(' ', '')

# %%
print(df2.columns)
# Out:
# Index(['Mode', 'NLC', 'ASC', 'Station', 'Coverage', 'year', 'day', 'dir',
#        'Total', 'Early',
#        ...
#        '0230-0245', '0245-0300', '0300-0315', '0315-0330', '0330-0345',
#        '0345-0400', '0400-0415', '0415-0430', '0430-0445', '0445-0500'],
#       dtype='object', length=111)

# %%
df2.nunique()
# Out:
# Mode           5
# NLC          405
# ASC          633
# Station      405
# Coverage       1
#             ...
# 0345-0400    107
# 0400-0415    104
# 0415-0430     92
# 0430-0445    549
# 0445-0500    819
# Length: 111, dtype: int64

# %%
df_in = df2.loc[df2.dir.str.contains('IN', na=False)]

# %%
df_in.head()
# Out:
#   Mode  NLC   ASC       Station              Coverage  year  day dir  \
# 0   LU  500  ACTu    Acton Town  Station entry / exit  2020  MTT  IN
# 1   LU  502  ALDu       Aldgate  Station entry / exit  2020  MTT  IN
# 2   LU  503  ALEu  Aldgate East  Station entry / exit  2020  MTT  IN
# 3   LU  505  ALPu      Alperton  Station entry / exit  2020  MTT  IN
# 4   LU  506  AMEu      Amersham  Station entry / exit  2020  MTT  IN
#
#          Total       Early  ...  0230-0245  0245-0300  0300-0315  0315-0330  \
# 0  3701.900000  288.200000  ...          0          0          0          0
# 1  2489.416667  172.583333  ...          0          0          0          0
# 2  3198.307692  103.000000  ...          0          0          0          0
# 3  2072.538462  360.230769  ...          0          0          0          0
# 4   980.466667  148.400000  ...          0          0          0          0
#
#    0330-0345  0345-0400  0400-0415  0415-0430  0430-0445  0445-0500
# ...

# %%
df_in.shape
# Out:
# (7403, 111)

# %%
df_out = df2.loc[df2.dir.str.contains('OUT', na=False)]

# %%
df_out.head()
# Out:
#     Mode  NLC   ASC       Station              Coverage  year  day  dir  \
# 264   LU  500  ACTu    Acton Town  Station entry / exit  2020  MTT  OUT
# 265   LU  502  ALDu       Aldgate  Station entry / exit  2020  MTT  OUT
# 266   LU  503  ALEu  Aldgate East  Station entry / exit  2020  MTT  OUT
# 267   LU  505  ALPu      Alperton  Station entry / exit  2020  MTT  OUT
# 268   LU  506  AMEu      Amersham  Station entry / exit  2020  MTT  OUT
#
#            Total       Early  ...  0230-0245  0245-0300  0300-0315  0315-0330  \
# 264  3655.100000  205.000000  ...          0          0          0          0
# 265  2822.083333  171.666667  ...          0          0          0          0
# 266  3005.461538  146.076923  ...          0          0          0          0
# 267  2194.692308   87.769231  ...          0          0          0          0
# 268   965.000000   16.400000  ...          0          0          0          0
#
# ...

# %%
df_out.shape
# Out:
# (7403, 111)

# %% [markdown]
# ### Splitting each of the datasets ('df_in' and 'df_out') by year for easy date assignment

# %%
# subset of In dataset by 2018
df_2018_in = df_in.loc[df_in.year == 2018]

# subset of In dataset by 2019
df_2019_in = df_in.loc[df_in.year == 2019]

# subset of In dataset by 2020
df_2020_in = df_in.loc[df_in.year == 2020]

# subset of In dataset by 2021
df_2021_in = df_in.loc[df_in.year == 2021]

# subset of OUT dataset by 2018
df_2018_out = df_out.loc[df_out.year == 2018]

# subset of OUT dataset by 2019
df_2019_out = df_out.loc[df_out.year == 2019]

# subset of OUT dataset by 2020
df_2020_out = df_out.loc[df_out.year == 2020]

# subset of OUT dataset by 2020
df_2021_out = df_out.loc[df_out.year == 2021]

# %%
# dataframes = [df_2018_in, df_2019_in, df_2020_in, df_2021_in, 
#                df_2018_out, df_2019_out, df_2020_out, df_2021_out]

# for df in dataframes:
#     display(df)


from IPython.display import display

display(df_2018_in, df_2018_out, df_2019_in, df_2019_out, df_2020_in, df_2020_out, df_2021_in, df_2021_out)
# Out:
#           Mode   NLC   ASC                 Station              Coverage  \
# 8598        LU   500   ACT              Acton Town  Station entry / exit
# 8599        LU   502   ALD                 Aldgate  Station entry / exit
# 8600        LU   503   ALE            Aldgate East  Station entry / exit
# 8601        LU   505   ALP                Alperton  Station entry / exit
# 8602        LU   506   AME                Amersham  Station entry / exit
# ...        ...   ...   ...                     ...                   ...
# 11709  TfLRail  6883  MNPr              Manor Park  Station entry / exit
# 11710  TfLRail  6970  MYLr                Maryland  Station entry / exit
# 11711  TfLRail  3000  AMLr         Acton Main Line  Station entry / exit
# 11712  TfLRail  3191  HANr                 Hanwell  Station entry / exit
# 11713  TfLRail  7091  HAFr  Heathrow Terminal 4 EL  Station entry / exit
#
#        year  day dir    Total  Early  ...  0230-0245  0245-0300  0300-0315  \
# ...

# %% [markdown]
# ### Applying melt() function to prepare the data for time series forecasting

# %%
melt = df2.melt(id_vars=['id', 'Mode', 'NLC', 'ASC', 'Station', 'Coverage', 'year', 'day', 'dir', 'Total', 'Early', 'AMPeak', 'InterPeak', 'PMPeak', 'Evening', 'Late'], var_name='15mins_interval', value_name='Count')
melt.head()
# Out:
#    id Mode  NLC   ASC       Station              Coverage  year  day dir  \
# 0   1   LU  500  ACTu    Acton Town  Station entry / exit  2020  MTT  IN
# 1   2   LU  502  ALDu       Aldgate  Station entry / exit  2020  MTT  IN
# 2   3   LU  503  ALEu  Aldgate East  Station entry / exit  2020  MTT  IN
# 3   4   LU  505  ALPu      Alperton  Station entry / exit  2020  MTT  IN
# 4   5   LU  506  AMEu      Amersham  Station entry / exit  2020  MTT  IN
#
#          Total       Early       AMPeak    InterPeak       PMPeak     Evening  \
# 0  3701.900000  288.200000  1101.200000  1185.700000   824.200000  213.200000
# 1  2489.416667  172.583333   520.166667   622.000000   920.000000  208.416667
# 2  3198.307692  103.000000   472.692308  1063.923077  1126.461538  333.230769
# 3  2072.538462  360.230769   667.846154   505.692308   408.538462   99.384615
# 4   980.466667  148.400000   424.666667   256.600000   124.133333   21.066667
#
#         Late 15mins_interval     Count
# ...

# %%
melt['15mins_interval'] = melt['15mins_interval'].str[:4]
melt.head()
# Out:
#    id Mode  NLC   ASC       Station              Coverage  year  day dir  \
# 0   1   LU  500  ACTu    Acton Town  Station entry / exit  2020  MTT  IN
# 1   2   LU  502  ALDu       Aldgate  Station entry / exit  2020  MTT  IN
# 2   3   LU  503  ALEu  Aldgate East  Station entry / exit  2020  MTT  IN
# 3   4   LU  505  ALPu      Alperton  Station entry / exit  2020  MTT  IN
# 4   5   LU  506  AMEu      Amersham  Station entry / exit  2020  MTT  IN
#
#          Total       Early       AMPeak    InterPeak       PMPeak     Evening  \
# 0  3701.900000  288.200000  1101.200000  1185.700000   824.200000  213.200000
# 1  2489.416667  172.583333   520.166667   622.000000   920.000000  208.416667
# 2  3198.307692  103.000000   472.692308  1063.923077  1126.461538  333.230769
# 3  2072.538462  360.230769   667.846154   505.692308   408.538462   99.384615
# 4   980.466667  148.400000   424.666667   256.600000   124.133333   21.066667
#
#         Late 15mins_interval     Count
# ...

# %%
melt['15mins_interval'] = melt['15mins_interval'].astype(str).str[:2] + ':' + melt['15mins_interval'].astype(str).str[2:]

# %%
melt.shape
# Out:
# (1421376, 18)

# %%
melt['15mins_interval'] = pd.to_datetime(melt['15mins_interval'], format='%H:%M').dt.time

# %%
melt['Count'] = round(melt['Count'], 0)

# %%
melt.head(10)
# Out:
#    id Mode  NLC   ASC       Station              Coverage  year  day dir  \
# 0   1   LU  500  ACTu    Acton Town  Station entry / exit  2020  MTT  IN
# 1   2   LU  502  ALDu       Aldgate  Station entry / exit  2020  MTT  IN
# 2   3   LU  503  ALEu  Aldgate East  Station entry / exit  2020  MTT  IN
# 3   4   LU  505  ALPu      Alperton  Station entry / exit  2020  MTT  IN
# 4   5   LU  506  AMEu      Amersham  Station entry / exit  2020  MTT  IN
# 5   6   LU  507  ANGu         Angel  Station entry / exit  2020  MTT  IN
# 6   7   LU  508  ARCu       Archway  Station entry / exit  2020  MTT  IN
# 7   8   LU  509  AGRu   Arnos Grove  Station entry / exit  2020  MTT  IN
# 8   9   LU  510  ARLu       Arsenal  Station entry / exit  2020  MTT  IN
# 9  10   LU  511  BSTu  Baker Street  Station entry / exit  2020  MTT  IN
#
#          Total       Early       AMPeak    InterPeak       PMPeak  \
# 0  3701.900000  288.200000  1101.200000  1185.700000   824.200000
# ...

# %%
melt_test = melt

# %%
melt['year'] = melt['year'].astype(str).astype('datetime64')

# %%
melt['year'] = melt['year'].dt.year

# %%
melt['year'].head()
# Out:
# 0    2020
# 1    2020
# 2    2020
# 3    2020
# 4    2020
# Name: year, dtype: int64

# %%
melt_bi = melt.loc[melt.year == 2021]

# %%
melt_bi.shape
# Out:
# (300288, 18)

# %%
melt_bi.tail(50)
# Out:
#            id Mode   NLC   ASC          Station              Coverage  year  \
# 1412784  6215  EZL  6872  BREr        Brentwood  Station entry / exit  2021
# 1412785  6216  EZL  3176  BNMr          Burnham  Station entry / exit  2021
# 1412786  6217  EZL  6874  CTHr   Chadwell Heath  Station entry / exit  2021
# 1412787  6218  EZL  6876  FOGr      Forest Gate  Station entry / exit  2021
# 1412788  6219  EZL  6877  GDPr       Gidea Park  Station entry / exit  2021
# 1412789  6220  EZL  6878  GMYr        Goodmayes  Station entry / exit  2021
# 1412790  6221  EZL  3191  HANr          Hanwell  Station entry / exit  2021
# 1412791  6222  EZL  6879  HROr      Harold Wood  Station entry / exit  2021
# 1412792  6223  EZL  6881  IFDr           Ilford  Station entry / exit  2021
# 1412793  6224  EZL  3170  IVRr             Iver  Station entry / exit  2021
# 1412794  6225  EZL  3171  LNYr          Langley  Station entry / exit  2021
# ...

# %% [markdown]
# ### Converting the melted data to csv file for easy access

# %%
# melt.to_csv('melted_data_forecast1.csv', index=False)

# %%
melt_bi.to_csv('melted_data_forecast_bi.csv', index=False)

# %%
forecast_df = melt

# %%
forecast_df.head()
# Out:
#    id Mode  NLC   ASC       Station              Coverage  year  day dir  \
# 0   1   LU  500  ACTu    Acton Town  Station entry / exit  2020  MTT  IN
# 1   2   LU  502  ALDu       Aldgate  Station entry / exit  2020  MTT  IN
# 2   3   LU  503  ALEu  Aldgate East  Station entry / exit  2020  MTT  IN
# 3   4   LU  505  ALPu      Alperton  Station entry / exit  2020  MTT  IN
# 4   5   LU  506  AMEu      Amersham  Station entry / exit  2020  MTT  IN
#
#          Total       Early       AMPeak    InterPeak       PMPeak     Evening  \
# 0  3701.900000  288.200000  1101.200000  1185.700000   824.200000  213.200000
# 1  2489.416667  172.583333   520.166667   622.000000   920.000000  208.416667
# 2  3198.307692  103.000000   472.692308  1063.923077  1126.461538  333.230769
# 3  2072.538462  360.230769   667.846154   505.692308   408.538462   99.384615
# 4   980.466667  148.400000   424.666667   256.600000   124.133333   21.066667
#
#         Late 15mins_interval     Count
# ...

# %%
forecast_df['15mins_interval'].unique()
# Out:
# array([datetime.time(5, 0), datetime.time(5, 15), datetime.time(5, 30),
#        datetime.time(5, 45), datetime.time(6, 0), datetime.time(6, 15),
#        datetime.time(6, 30), datetime.time(6, 45), datetime.time(7, 0),
#        datetime.time(7, 15), datetime.time(7, 30), datetime.time(7, 45),
#        datetime.time(8, 0), datetime.time(8, 15), datetime.time(8, 30),
#        datetime.time(8, 45), datetime.time(9, 0), datetime.time(9, 15),
#        datetime.time(9, 30), datetime.time(9, 45), datetime.time(10, 0),
#        datetime.time(10, 15), datetime.time(10, 30),
#        datetime.time(10, 45), datetime.time(11, 0), datetime.time(11, 15),
#        datetime.time(11, 30), datetime.time(11, 45), datetime.time(12, 0),
#        datetime.time(12, 15), datetime.time(12, 30),
#        datetime.time(12, 45), datetime.time(13, 0), datetime.time(13, 15),
#        datetime.time(13, 30), datetime.time(13, 45), datetime.time(14, 0),
#        datetime.time(14, 15), datetime.time(14, 30),
# ...

# %%
forecast_df['year'].unique()
# Out:
# array([2020, 2021, 2017, 2018, 2019], dtype=int64)
